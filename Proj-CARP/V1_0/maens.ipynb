# %%
import numpy as np
from main import *
from path_scanning import *
from copy import deepcopy
from time import perf_counter
from random import choice, randrange, randint

# %%
info = read_file("sample2.dat")
sp = shortest_path(info["graph"])
pop_size = 50
init_population = generate_route(sp, info["tasks"], info["depot"], info["capacity"], info["num_vehicles"], pop_size)
for p in init_population:
    print(p)
    print(len(p))
    print()
# Out:
# [[((33, 31), 43), ((32, 31), 30), ((31, 30), 58), ((31, 34), 86), ((30, 22), 40), ((16, 14), 26), ((22, 74), 17), ((34, 40), 15)], [((14, 17), 38), ((67, 65), 45), ((74, 21), 24), ((13, 12), 7), ((64, 62), 21), ((12, 15), 13), ((54, 55), 6), ((18, 17), 41), ((18, 19), 32), ((18, 20), 38), ((15, 11), 29), ((41, 56), 14)], [((21, 20), 17), ((62, 61), 30), ((42, 43), 78), ((56, 57), 78), ((19, 75), 8), ((53, 51), 4), ((20, 50), 2), ((50, 48), 10), ((51, 49), 2), ((60, 59), 39), ((65, 61), 16), ((49, 48), 8), ((11, 10), 32)], [((47, 46), 10), ((48, 46), 9), ((61, 59), 23), ((46, 45), 33), ((59, 57), 33), ((10, 58), 78), ((45, 43), 13), ((9, 8), 20), ((44, 43), 12), ((43, 58), 28), ((57, 58), 25), ((57, 68), 32)], [((58, 68), 11), ((68, 3), 75), ((4, 3), 56), ((3, 1), 17), ((2, 1), 14), ((0, 1), 32)]]
# 5
#
# ...

# %%
def SBX(p1, p2):
    """crossover"""
    r1, r2 = choice(p1), choice(p2)
    range1, range2 = randint(len(r1) - 1), randint(len(r2) - 1)
    r11, r12 = r1[:range1], r1[range1:]
    r21, r22 = r2[:range2], r2[range2:]

# %%
start = end = perf_counter()
pop = init_population
while end - start < 2:
    im_pop = deepcopy(pop)
    for i in range(pop_size):
        p1, p2 = choice(pop), choice(pop)
        

    

    end = perf_counter()
